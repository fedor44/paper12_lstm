# %% [markdown]
# <a href="https://colab.research.google.com/github/fedor44/paper12_lstm/blob/main/Untitled74.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

# 감성 분석 데이터 파일
df_sentiment  = pd.read_csv('/content/drive/MyDrive/paper/news/finbert_ok.csv')

# 날짜 (년-월-일) 정리
df_sentiment['date'] = pd.to_datetime(df_sentiment['publishDate']).dt.date
df_sentiment
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#       Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0                0             0             0             1           0
# 1                1             1             1             2           0
# 2                2             2             2             3           0
# 3                3             3             3             4           0
# 4                4             4             4            13           0
# ...            ...           ...           ...           ...         ...
# 3315          3315          3315          3315          9209           0
# 3316          3316          3316          3316          9212           0
# 3317          3317          3317          3317          9213           0
# 3318          3318          3318          3318          9214           0
# 3319          3319          3319          3319          9219           0
#
#      ticker                                           headline  \
# 0      AVGO           4 stocks watch Friday Broadcom Lululemon
# 1      AVGO  Broadcom Q2 results Q3 revenue guidance beat W...
# 2      AVGO  Broadcom NonGAAP EPS $10.32 beats $0.18 revenu...
# 3      MSFT  Microsoft deal Nvidiabacked CoreWeave AI proce...
# 4      AAPL  Apple says developers generated $1.1T App Stor...
# ...     ...                                                ...
# 3315   AAPL  Oppenheimer Global ESG Revenue ETF ESGF Decemb...
# 3316   MSFT   Microsoft acquiring cloud provider Avere Systems
# 3317   MSFT  Nuance notes enhancements driving platform new...
# 3318   AAPL  Apple analyst says low iPhone X estimates stil...
# 3319   AAPL  Apple instructs Stores offer $29 battery regar...
#
#               publishDate  vaderSentiment  finbertSentiment  \
# 0      2023-06-02 8:43:52               0                 2
# 1     2023-06-01 16:53:08               0                 0
# 2     2023-06-01 16:19:03               2                 2
# 3     2023-06-01 14:40:10               0                 2
# 4     2023-05-31 13:44:35               0                 2
# ...                   ...             ...               ...
# 3315  2018-01-04 08:20:02               1                 2
# 3316  2018-01-03 13:22:20               0                 2
# 3317  2018-01-03 11:26:04               0                 0
# 3318  2018-01-02 13:00:09               0                 1
# 3319  2018-01-02 08:18:55               0                 2
#
#       finetunedFinbertSentiment  vaderScore  finbertScore  \
# 0                             2      0.1882     -0.015393
# 1                             0      0.2511      0.905228
# 2                             0      0.0039      0.133304
# 3                             2      0.6366      0.080946
# 4                             0      0.1811      0.094119
# ...                         ...         ...           ...
# 3315                          2     -0.0975      0.019440
# 3316                          2      0.0643      0.056508
# 3317                          0      0.1677      0.598611
# 3318                          1      0.2982     -0.926437
# 3319                          2      0.3415      0.075669
#
#       finetunedFinbertScore  GPT4Sentiment        date
# 0                  0.003025              2  2023-06-02
# 1                  0.951204              0  2023-06-01
# 2                  0.944922              0  2023-06-01
# 3                  0.035941              2  2023-06-01
# 4                  0.788899              0  2023-05-31
# ...                     ...            ...         ...
# 3315               0.004638              2  2018-01-04
# 3316               0.074213              2  2018-01-03
# 3317               0.933078              0  2018-01-03
# 3318              -0.936811              1  2018-01-02
# 3319               0.097032              2  2018-01-02
#
# [3320 rows x 16 columns]

# %%
import pandas as pd

# Yahoo Finance에서 제공 금융 데이터 로드
import yfinance as yf

# 데이터 출처 Yahoo Finance
# 금융 데이터 로드
tickers = ['AAPL','MSFT','AVGO']
start = '2018-01-01'
end = '2023-05-31'
df_ticker_info = pd.DataFrame()
for ticker in tickers:
    ticker_yf = yf.Ticker(ticker)
    if df_ticker_info.empty:
        df_ticker_info = ticker_yf.history(start = start, end = end)
        df_ticker_info['ticker']= ticker
    else:
        data_temp = ticker_yf.history(start = start, end = end)
        data_temp['ticker']= ticker
        df_ticker_info = pd.concat([df_ticker_info, data_temp])

df_ticker_info
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-01-02 00:00:00-05:00   40.175166   40.680425   39.962672   40.670979
# 2018-01-03 00:00:00-05:00   40.734738   41.211665   40.600161   40.663906
# 2018-01-04 00:00:00-05:00   40.737073   40.956650   40.628468   40.852764
# 2018-01-05 00:00:00-05:00   40.949575   41.405251   40.857495   41.317894
# 2018-01-08 00:00:00-05:00   41.164436   41.461924   41.065270   41.164436
# ...                               ...         ...         ...         ...
# 2023-05-23 00:00:00-04:00  677.247109  685.435162  668.794273  673.187378
# 2023-05-24 00:00:00-04:00  668.225596  671.039937  662.949920  666.352661
# 2023-05-25 00:00:00-04:00  685.847030  718.187523  677.374622  714.667114
# 2023-05-26 00:00:00-04:00  732.935907  799.175973  732.533884  796.969604
# 2023-05-30 00:00:00-04:00  818.925412  903.904942  783.319535  787.761719
#
#                               Volume  Dividends  Stock Splits ticker
# Date
# 2018-01-02 00:00:00-05:00  102223600        0.0           0.0   AAPL
# 2018-01-03 00:00:00-05:00  118071600        0.0           0.0   AAPL
# 2018-01-04 00:00:00-05:00   89738400        0.0           0.0   AAPL
# 2018-01-05 00:00:00-05:00   94640000        0.0           0.0   AAPL
# 2018-01-08 00:00:00-05:00   82271200        0.0           0.0   AAPL
# ...                              ...        ...           ...    ...
# 2023-05-23 00:00:00-04:00    3608800        0.0           0.0   AVGO
# 2023-05-24 00:00:00-04:00    2302100        0.0           0.0   AVGO
# 2023-05-25 00:00:00-04:00    4926300        0.0           0.0   AVGO
# 2023-05-26 00:00:00-04:00    8250000        0.0           0.0   AVGO
# 2023-05-30 00:00:00-04:00   11691200        0.0           0.0   AVGO
#
# [4083 rows x 8 columns]

# %%
import numpy as np

# pct_change 함수를 이용, 각 날짜별 종가를 이용하여 수익률을 계산
df_ticker_info['currRet'] = df_ticker_info['Close'].pct_change()

# ticker가 바뀔 때는 정확한 수익률을 계산할 수 없으므로 첫행은 NaN 처리
temp_df_ticker_info = df_ticker_info.loc[:, 'currRet'].copy()
for i in range(len(df_ticker_info)-1):
  if df_ticker_info.iloc[i]['ticker'] != df_ticker_info.iloc[i+1]['ticker']:
    temp_df_ticker_info.iloc[i+1] = np.nan

df_ticker_info['currRet'] = temp_df_ticker_info

# 전일, 당일, 후일의 데이터를 활용하여 이벤트 수익률을 계산하여 이벤트에 따른 주가의 변동을 보다 정확하게 측정
# currRet(t-1) + currRet(t) + currRet(t+1) -> 뉴스 데이터 전일, 당일, 후일의 수익
df_ticker_info['eventRet'] = df_ticker_info['currRet'] + df_ticker_info['currRet'].shift(-1) + df_ticker_info['currRet'].shift(1)

# 날짜 (년-월-일) 정리
df_ticker_info.reset_index(inplace=True)
df_ticker_info['date'] = pd.to_datetime(df_ticker_info['Date']).dt.date

df_ticker_info
# Out:
#       index                      Date        Open        High         Low  \
# 0         0 2018-01-02 00:00:00-05:00   40.175166   40.680425   39.962672
# 1         1 2018-01-03 00:00:00-05:00   40.734738   41.211665   40.600161
# 2         2 2018-01-04 00:00:00-05:00   40.737073   40.956650   40.628468
# 3         3 2018-01-05 00:00:00-05:00   40.949575   41.405251   40.857495
# 4         4 2018-01-08 00:00:00-05:00   41.164436   41.461924   41.065270
# ...     ...                       ...         ...         ...         ...
# 4078   4078 2023-05-23 00:00:00-04:00  677.247109  685.435162  668.794273
# 4079   4079 2023-05-24 00:00:00-04:00  668.225596  671.039937  662.949920
# 4080   4080 2023-05-25 00:00:00-04:00  685.847030  718.187523  677.374622
# 4081   4081 2023-05-26 00:00:00-04:00  732.935907  799.175973  732.533884
# 4082   4082 2023-05-30 00:00:00-04:00  818.925412  903.904942  783.319535
#
#            Close     Volume  Dividends  Stock Splits ticker   currRet  \
# 0      40.670979  102223600        0.0           0.0   AAPL       NaN
# 1      40.663906  118071600        0.0           0.0   AAPL -0.000174
# 2      40.852764   89738400        0.0           0.0   AAPL  0.004644
# 3      41.317894   94640000        0.0           0.0   AAPL  0.011386
# 4      41.164436   82271200        0.0           0.0   AAPL -0.003714
# ...          ...        ...        ...           ...    ...       ...
# 4078  673.187378    3608800        0.0           0.0   AVGO  0.011984
# 4079  666.352661    2302100        0.0           0.0   AVGO -0.010153
# 4080  714.667114    4926300        0.0           0.0   AVGO  0.072506
# 4081  796.969604    8250000        0.0           0.0   AVGO  0.115162
# 4082  787.761719   11691200        0.0           0.0   AVGO -0.011554
#
#       eventRet        date
# 0          NaN  2018-01-02
# 1          NaN  2018-01-03
# 2     0.015856  2018-01-04
# 3     0.012316  2018-01-05
# 4     0.007557  2018-01-08
# ...        ...         ...
# 4078 -0.003855  2023-05-23
# 4079  0.074337  2023-05-24
# 4080  0.177515  2023-05-25
# 4081  0.176114  2023-05-26
# 4082       NaN  2023-05-30
#
# [4083 rows x 13 columns]

# %%
df_ticker_info.to_csv('/content/drive/MyDrive/paper/stock/stock_ok.csv')

# %%
# 주식 데이터 파일
df_stock = pd.read_csv('/content/drive/MyDrive/paper/stock/stock_ok.csv')
df_stock['date'] = pd.to_datetime(df_stock['date'])

df_stock
# Out:
#       Unnamed: 0  index                       Date        Open        High  \
# 0              0      0  2018-01-02 00:00:00-05:00   40.175166   40.680425
# 1              1      1  2018-01-03 00:00:00-05:00   40.734738   41.211665
# 2              2      2  2018-01-04 00:00:00-05:00   40.737073   40.956650
# 3              3      3  2018-01-05 00:00:00-05:00   40.949575   41.405251
# 4              4      4  2018-01-08 00:00:00-05:00   41.164436   41.461924
# ...          ...    ...                        ...         ...         ...
# 4078        4078   4078  2023-05-23 00:00:00-04:00  677.247109  685.435162
# 4079        4079   4079  2023-05-24 00:00:00-04:00  668.225596  671.039937
# 4080        4080   4080  2023-05-25 00:00:00-04:00  685.847030  718.187523
# 4081        4081   4081  2023-05-26 00:00:00-04:00  732.935907  799.175973
# 4082        4082   4082  2023-05-30 00:00:00-04:00  818.925412  903.904942
#
#              Low       Close     Volume  Dividends  Stock Splits ticker  \
# 0      39.962672   40.670979  102223600        0.0           0.0   AAPL
# 1      40.600161   40.663906  118071600        0.0           0.0   AAPL
# 2      40.628468   40.852764   89738400        0.0           0.0   AAPL
# 3      40.857495   41.317894   94640000        0.0           0.0   AAPL
# 4      41.065270   41.164436   82271200        0.0           0.0   AAPL
# ...          ...         ...        ...        ...           ...    ...
# 4078  668.794273  673.187378    3608800        0.0           0.0   AVGO
# 4079  662.949920  666.352661    2302100        0.0           0.0   AVGO
# 4080  677.374622  714.667114    4926300        0.0           0.0   AVGO
# 4081  732.533884  796.969604    8250000        0.0           0.0   AVGO
# 4082  783.319535  787.761719   11691200        0.0           0.0   AVGO
#
#        currRet  eventRet       date
# 0          NaN       NaN 2018-01-02
# 1    -0.000174       NaN 2018-01-03
# 2     0.004644  0.015856 2018-01-04
# 3     0.011386  0.012316 2018-01-05
# 4    -0.003714  0.007557 2018-01-08
# ...        ...       ...        ...
# 4078  0.011984 -0.003855 2023-05-23
# 4079 -0.010153  0.074337 2023-05-24
# 4080  0.072506  0.177515 2023-05-25
# 4081  0.115162  0.176114 2023-05-26
# 4082 -0.011554       NaN 2023-05-30
#
# [4083 rows x 14 columns]

# %%
# 첫 번째 데이터프레임의 'date' 컬럼을 datetime 형식으로 변환
df_sentiment['date'] = pd.to_datetime(df_sentiment['date'])

# 두 번째 데이터프레임의 'date' 컬럼을 datetime 형식으로 변환
df_stock['date'] = pd.to_datetime(df_stock['date'])

# 주식 데이터와 감성 분석 데이터 결합
# df_stock 에 df_sentiment 를 left 조인
df = pd.merge(df_stock, df_sentiment, how='left', left_on=['date','ticker'], right_on=['date','ticker'])

df
# Out:
#       Unnamed: 0_x  index                       Date        Open        High  \
# 0                0      0  2018-01-02 00:00:00-05:00   40.175166   40.680425
# 1                0      0  2018-01-02 00:00:00-05:00   40.175166   40.680425
# 2                1      1  2018-01-03 00:00:00-05:00   40.734738   41.211665
# 3                2      2  2018-01-04 00:00:00-05:00   40.737073   40.956650
# 4                2      2  2018-01-04 00:00:00-05:00   40.737073   40.956650
# ...            ...    ...                        ...         ...         ...
# 5400          4078   4078  2023-05-23 00:00:00-04:00  677.247109  685.435162
# 5401          4079   4079  2023-05-24 00:00:00-04:00  668.225596  671.039937
# 5402          4080   4080  2023-05-25 00:00:00-04:00  685.847030  718.187523
# 5403          4081   4081  2023-05-26 00:00:00-04:00  732.935907  799.175973
# 5404          4082   4082  2023-05-30 00:00:00-04:00  818.925412  903.904942
#
#              Low       Close     Volume  Dividends  Stock Splits  ...  \
# 0      39.962672   40.670979  102223600        0.0           0.0  ...
# 1      39.962672   40.670979  102223600        0.0           0.0  ...
# 2      40.600161   40.663906  118071600        0.0           0.0  ...
# 3      40.628468   40.852764   89738400        0.0           0.0  ...
# 4      40.628468   40.852764   89738400        0.0           0.0  ...
# ...          ...         ...        ...        ...           ...  ...
# 5400  668.794273  673.187378    3608800        0.0           0.0  ...
# 5401  662.949920  666.352661    2302100        0.0           0.0  ...
# 5402  677.374622  714.667114    4926300        0.0           0.0  ...
# 5403  732.533884  796.969604    8250000        0.0           0.0  ...
# 5404  783.319535  787.761719   11691200        0.0           0.0  ...
#
#      Unnamed: 0_y                                           headline  \
# 0             0.0  Apple analyst says low iPhone X estimates stil...
# 1             0.0  Apple instructs Stores offer $29 battery regar...
# 2             NaN                                                NaN
# 3             0.0  Apple confirms devices affected processor expl...
# 4             0.0     Reports With shares vesting Iovine leave Apple
# ...           ...                                                ...
# 5400          NaN                                                NaN
# 5401          0.0  Broadcom slips even BofA says Apple deal remov...
# 5402          NaN                                                NaN
# 5403          NaN                                                NaN
# 5404          0.0  Broadcom rises Wall Street believes infrastruc...
#
#               publishDate vaderSentiment  finbertSentiment  \
# 0     2018-01-02 13:00:09            0.0               1.0
# 1     2018-01-02 08:18:55            0.0               2.0
# 2                     NaN            NaN               NaN
# 3     2018-01-04 19:29:55            1.0               2.0
# 4     2018-01-04 18:06:17            0.0               1.0
# ...                   ...            ...               ...
# 5400                  NaN            NaN               NaN
# 5401   2023-05-24 8:40:21            0.0               1.0
# 5402                  NaN            NaN               NaN
# 5403                  NaN            NaN               NaN
# 5404  2023-05-30 14:36:29            0.0               0.0
#
#       finetunedFinbertSentiment  vaderScore  finbertScore  \
# 0                           1.0      0.2982     -0.926437
# 1                           2.0      0.3415      0.075669
# 2                           NaN         NaN           NaN
# 3                           1.0     -0.1583     -0.146010
# 4                           2.0      0.3975     -0.765041
# ...                         ...         ...           ...
# 5400                        NaN         NaN           NaN
# 5401                        1.0      0.3404     -0.805930
# 5402                        NaN         NaN           NaN
# 5403                        NaN         NaN           NaN
# 5404                        0.0      0.2401      0.928987
#
#       finetunedFinbertScore GPT4Sentiment
# 0                 -0.936811           1.0
# 1                  0.097032           2.0
# 2                       NaN           NaN
# 3                 -0.589952           2.0
# 4                 -0.014662           2.0
# ...                     ...           ...
# 5400                    NaN           NaN
# 5401              -0.953930           1.0
# 5402                    NaN           NaN
# 5403                    NaN           NaN
# 5404               0.950671           0.0
#
# [5405 rows x 28 columns]
# Warning: Total number of columns (28) exceeds max_columns (20) limiting to first (20) columns.

# %%
# 데이터프레임에서 모든 "Unnamed" 열 제거
final_df = df.loc[:, ~df.columns.str.startswith('Unnamed')]

# NaN 이 있는 행 드롭
#final_df = final_df.dropna()

final_df.to_csv('/content/drive/MyDrive/paper/stock/final_ok.csv')

final_df
# Out:
#       index                       Date        Open        High         Low  \
# 0         0  2018-01-02 00:00:00-05:00   40.175166   40.680425   39.962672
# 1         0  2018-01-02 00:00:00-05:00   40.175166   40.680425   39.962672
# 2         1  2018-01-03 00:00:00-05:00   40.734738   41.211665   40.600161
# 3         2  2018-01-04 00:00:00-05:00   40.737073   40.956650   40.628468
# 4         2  2018-01-04 00:00:00-05:00   40.737073   40.956650   40.628468
# ...     ...                        ...         ...         ...         ...
# 5400   4078  2023-05-23 00:00:00-04:00  677.247109  685.435162  668.794273
# 5401   4079  2023-05-24 00:00:00-04:00  668.225596  671.039937  662.949920
# 5402   4080  2023-05-25 00:00:00-04:00  685.847030  718.187523  677.374622
# 5403   4081  2023-05-26 00:00:00-04:00  732.935907  799.175973  732.533884
# 5404   4082  2023-05-30 00:00:00-04:00  818.925412  903.904942  783.319535
#
#            Close     Volume  Dividends  Stock Splits ticker  ...       date  \
# 0      40.670979  102223600        0.0           0.0   AAPL  ... 2018-01-02
# 1      40.670979  102223600        0.0           0.0   AAPL  ... 2018-01-02
# 2      40.663906  118071600        0.0           0.0   AAPL  ... 2018-01-03
# 3      40.852764   89738400        0.0           0.0   AAPL  ... 2018-01-04
# 4      40.852764   89738400        0.0           0.0   AAPL  ... 2018-01-04
# ...          ...        ...        ...           ...    ...  ...        ...
# 5400  673.187378    3608800        0.0           0.0   AVGO  ... 2023-05-23
# 5401  666.352661    2302100        0.0           0.0   AVGO  ... 2023-05-24
# 5402  714.667114    4926300        0.0           0.0   AVGO  ... 2023-05-25
# 5403  796.969604    8250000        0.0           0.0   AVGO  ... 2023-05-26
# 5404  787.761719   11691200        0.0           0.0   AVGO  ... 2023-05-30
#
#                                                headline          publishDate  \
# 0     Apple analyst says low iPhone X estimates stil...  2018-01-02 13:00:09
# 1     Apple instructs Stores offer $29 battery regar...  2018-01-02 08:18:55
# 2                                                   NaN                  NaN
# 3     Apple confirms devices affected processor expl...  2018-01-04 19:29:55
# 4        Reports With shares vesting Iovine leave Apple  2018-01-04 18:06:17
# ...                                                 ...                  ...
# 5400                                                NaN                  NaN
# 5401  Broadcom slips even BofA says Apple deal remov...   2023-05-24 8:40:21
# 5402                                                NaN                  NaN
# 5403                                                NaN                  NaN
# 5404  Broadcom rises Wall Street believes infrastruc...  2023-05-30 14:36:29
#
#      vaderSentiment finbertSentiment  finetunedFinbertSentiment  vaderScore  \
# 0               0.0              1.0                        1.0      0.2982
# 1               0.0              2.0                        2.0      0.3415
# 2               NaN              NaN                        NaN         NaN
# 3               1.0              2.0                        1.0     -0.1583
# 4               0.0              1.0                        2.0      0.3975
# ...             ...              ...                        ...         ...
# 5400            NaN              NaN                        NaN         NaN
# 5401            0.0              1.0                        1.0      0.3404
# 5402            NaN              NaN                        NaN         NaN
# 5403            NaN              NaN                        NaN         NaN
# 5404            0.0              0.0                        0.0      0.2401
#
#       finbertScore  finetunedFinbertScore  GPT4Sentiment
# 0        -0.926437              -0.936811            1.0
# 1         0.075669               0.097032            2.0
# 2              NaN                    NaN            NaN
# 3        -0.146010              -0.589952            2.0
# 4        -0.765041              -0.014662            2.0
# ...            ...                    ...            ...
# 5400           NaN                    NaN            NaN
# 5401     -0.805930              -0.953930            1.0
# 5402           NaN                    NaN            NaN
# 5403           NaN                    NaN            NaN
# 5404      0.928987               0.950671            0.0
#
# [5405 rows x 22 columns]
# Warning: Total number of columns (22) exceeds max_columns (20) limiting to first (20) columns.

# %%
df_aapl = final_df[final_df['ticker'] == 'AAPL']
df_msft = final_df[final_df['ticker'] == 'MSFT']
df_avgo = final_df[final_df['ticker'] == 'AVGO']

df_aapl.to_csv('/content/drive/MyDrive/paper/stock/df_aapl.csv')
df_msft.to_csv('/content/drive/MyDrive/paper/stock/df_msft.csv')
df_avgo.to_csv('/content/drive/MyDrive/paper/stock/df_avgo.csv')

# %%
#LSTM start
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

# 주식 정보 및 감성 분석 데이터 파일
df_aapl = pd.read_csv('/content/drive/MyDrive/paper/stock/df_aapl.csv')
df_msft = pd.read_csv('/content/drive/MyDrive/paper/stock/df_msft.csv')
df_avgo = pd.read_csv('/content/drive/MyDrive/paper/stock/df_avgo.csv')

# separate dates for future plotting
#df_aapl_date = pd.to_datetime(df_aapl['date'])
#df_msft_date = pd.to_datetime(df_msft['date'])
#df_avgo_date = pd.to_datetime(df_avgo['date'])

# 필요한 데이터만 남기고 정리
df_aapl_1 = df_aapl[['Open', 'High', 'Low', 'Close', 'Volume', 'vaderSentiment']]
df_aapl_2 = df_aapl[['Open', 'High', 'Low', 'Close', 'Volume', 'finbertSentiment']]
df_aapl_3 = df_aapl[['Open', 'High', 'Low', 'Close', 'Volume', 'finetunedFinbertSentiment']]

# 특성 선택 및 데이터 정규화
features_1 = ['Open', 'High', 'Low', 'Close', 'Volume', 'vaderSentiment']
features_2 = ['Open', 'High', 'Low', 'Close', 'Volume', 'finbertSentiment']
features_3 = ['Open', 'High', 'Low', 'Close', 'Volume', 'finetunedFinbertSentiment']
# 결측치 중립으로 처리
df_aapl_1['vaderSentiment'] = df_aapl_1['vaderSentiment'].fillna(2.0)
df_aapl_2['finbertSentiment'] = df_aapl_2['finbertSentiment'].fillna(2.0)
df_aapl_3['finetunedFinbertSentiment'] = df_aapl_3['finetunedFinbertSentiment'].fillna(2.0)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# <ipython-input-2-bae10919b83b>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aapl_1['vaderSentiment'] = df_aapl_1['vaderSentiment'].fillna(2.0)
# <ipython-input-2-bae10919b83b>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aapl_2['finbertSentiment'] = df_aapl_2['finbertSentiment'].fillna(2.0)
# <ipython-input-2-bae10919b83b>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aapl_3['finetunedFinbertSentiment'] = df_aapl_3['finetunedFinbertSentiment'].fillna(2.0)

# %%
#from tensorflow.keras.callbacks import EarlyStopping

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df_aapl_1[features_1])
#scaled_data = scaler.fit_transform(df_aapl_2[features_2])
#scaled_data = scaler.fit_transform(df_aapl_3[features_3])

# 데이터를 시퀀스로 변환하는 함수
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data)-seq_length):
        x = data[i:(i+seq_length)]
        y = data[i+seq_length, 3]  # 'Close' 가격을 예측 대상으로 설정
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 14  # 시퀀스 길이 설정
X, y = create_sequences(scaled_data, seq_length)

# 데이터 분할 (시간 기반 분할)
train_size = int(len(X) * 0.8)  # 훈련 데이터 크기를 전체 데이터의 70%로 설정
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 선택적으로 검증 세트 생성
val_size = int(len(X_train) * 0.2)  # 훈련 데이터의 20%를 검증 데이터로 설정
X_val, y_val = X_train[-val_size:], y_train[-val_size:]
X_train, y_train = X_train[:-val_size], y_train[:-val_size]

# LSTM 모델 구축 (LSTM 기본 활성화 함수 = tanh, sigmoid LSTM 그림 참조)
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25, activation='relu')) # 첫 번째 Dense 레이어에 ReLU 활성화 함수 적용
model.add(Dense(1))

# 모델 컴파일 (adam 학습률 = 0.001)
model.compile(optimizer='adam', loss='mean_squared_error')

# 조기 종료 콜백 설정
#monitor: 성능을 모니터링할 지표입니다. 여기서는 검증 데이터의 손실(val_loss)을 모니터링합니다.
#patience: 성능 개선이 없는 에폭을 얼마나 허용할지 지정합니다. 여기서는 10로 설정하여, 검증 손실이 10 에폭 동안 개선되지 않으면 학습을 중단합니다.
#restore_best_weights: True로 설정하면, 조기 종료 시점에서 가장 좋은 모델의 가중치를 복원합니다. 즉, 학습 과정에서 가장 낮은 검증 손실을 가진 모델의 가중치를 사용합니다.
#early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# 모델 학습
#model.fit(X_train, y_train, batch_size=32, epochs=200, validation_data=(X_test, y_test), callbacks=[early_stopping])
model.fit(X_train, y_train, batch_size=32, epochs=300, validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 47/47 [==============================] - 15s 109ms/step - loss: 0.0154 - val_loss: 0.0038
# Epoch 2/300
# 47/47 [==============================] - 1s 31ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 3/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 4/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 5/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 6/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 7/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0048
# Epoch 8/300
# 47/47 [==============================] - 1s 16ms/step - loss: 9.4430e-04 - val_loss: 0.0018
# Epoch 9/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 10/300
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0072
# Epoch 11/300
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5682e-04 - val_loss: 0.0058
# Epoch 12/300
# 47/47 [==============================] - 1s 24ms/step - loss: 7.9847e-04 - val_loss: 0.0045
# Epoch 13/300
# 47/47 [==============================] - 1s 24ms/step - loss: 8.9005e-04 - val_loss: 0.0030
# Epoch 14/300
# 47/47 [==============================] - 1s 26ms/step - loss: 8.4443e-04 - val_loss: 0.0078
# Epoch 15/300
# 47/47 [==============================] - 1s 18ms/step - loss: 8.5750e-04 - val_loss: 0.0058
# Epoch 16/300
# 47/47 [==============================] - 1s 16ms/step - loss: 7.7670e-04 - val_loss: 0.0060
# Epoch 17/300
# 47/47 [==============================] - 1s 15ms/step - loss: 6.6709e-04 - val_loss: 0.0076
# Epoch 18/300
# 47/47 [==============================] - 1s 16ms/step - loss: 6.9266e-04 - val_loss: 0.0027
# Epoch 19/300
# 47/47 [==============================] - 1s 16ms/step - loss: 6.6527e-04 - val_loss: 0.0105
# Epoch 20/300
# 47/47 [==============================] - 1s 16ms/step - loss: 6.6715e-04 - val_loss: 0.0044
# Epoch 21/300
# 47/47 [==============================] - 1s 15ms/step - loss: 5.9561e-04 - val_loss: 0.0075
# Epoch 22/300
# 47/47 [==============================] - 1s 16ms/step - loss: 5.6717e-04 - val_loss: 0.0091
# Epoch 23/300
# 47/47 [==============================] - 1s 16ms/step - loss: 5.8559e-04 - val_loss: 0.0057
# Epoch 24/300
# 47/47 [==============================] - 1s 16ms/step - loss: 6.4806e-04 - val_loss: 0.0027
# Epoch 25/300
# 47/47 [==============================] - 1s 16ms/step - loss: 6.0820e-04 - val_loss: 0.0042
# Epoch 26/300
300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.8936e-04 - val_loss: 0.0070
# Epoch 60/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.4001e-04 - val_loss: 0.0043
# Epoch 61/300
# 47/47 [==============================] - 1s 22ms/step - loss: 3.1359e-04 - val_loss: 0.0061
# Epoch 62/300
# 47/47 [==============================] - 1s 25ms/step - loss: 3.2043e-04 - val_loss: 0.0087
# Epoch 63/300
# 47/47 [==============================] - 1s 24ms/step - loss: 3.1227e-04 - val_loss: 0.0084
# Epoch 64/300
# 47/47 [==============================] - 1s 21ms/step - loss: 3.1625e-04 - val_loss: 0.0093
# Epoch 65/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.1759e-04 - val_loss: 0.0082
# Epoch 66/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.9538e-04 - val_loss: 0.0040
# Epoch 67/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.8362e-04 - val_loss: 0.0036
# Epoch 68/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.0800e-04 - val_loss: 0.0065
# Epoch 69/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.3957e-04 - val_loss: 0.0061
# Epoch 70/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.9306e-04 - val_loss: 0.0049
# Epoch 71/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.0924e-04 - val_loss: 0.0096
# Epoch 72/300
# 47/47 [==============================] - 1s 17ms/step - loss: 2.8547e-04 - val_loss: 0.0085
# Epoch 73/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.4105e-04 - val_loss: 0.0129
# Epoch 74/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.3026e-04 - val_loss: 0.0094
# Epoch 75/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6515e-04 - val_loss: 0.0096
# Epoch 76/300
# 47/47 [==============================] - 1s 15ms/step - loss: 2.9861e-04 - val_loss: 0.0090
# Epoch 77/300
# 47/47 [==============================] - 1s 19ms/step - loss: 2.6150e-04 - val_loss: 0.0056
# Epoch 78/300
# 47/47 [==============================] - 1s 25ms/step - loss: 3.0666e-04 - val_loss: 0.0088
# Epoch 79/300
# 47/47 [==============================] - 1s 24ms/step - loss: 3.0223e-04 - val_loss: 0.0127
# Epoch 80/300
# 47/47 [==============================] - 1s 24ms/step - loss: 2.8969e-04 - val_loss: 0.0051
# Epoch 81/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.0112e-04 - val_loss: 0.0064
# Epoch 82/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.8879e-04 - val_loss: 0.0076
# Epoch 83/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.0129e-04 - val_loss: 0.0108
# Epoch 84/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.7665e-04 - val_loss: 0.0084
# Epoch 85/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.7707e-04 - val_loss: 0.0078
# Epoch 86/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6359e-04 - val_loss: 0.0096
# Epoch 87/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6538e-04 - val_loss: 0.0089
# Epoch 88/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.7685e-04 - val_loss: 0.0068
# Epoch 89/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6730e-04 - val_loss: 0.0052
# Epoch 90/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.1039e-04 - val_loss: 0.0044
# Epoch 91/300
# 47/47 [==============================] - 1s 17ms/step - loss: 2.7018e-04 - val_loss: 0.0086
# Epoch 92/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.5478e-04 - val_loss: 0.0090
# Epoch 93/300
# 47/47 [==============================] - 1s 23ms/step - loss: 3.0516e-04 - val_loss: 0.0092
# Epoch 94/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.4993e-04 - val_loss: 0.0109
# Epoch 95/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.7014e-04 - val_loss: 0.0091
# Epoch 96/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.6229e-04 - val_loss: 0.0073
# Epoch 97/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6213e-04 - val_loss: 0.0065
# Epoch 98/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.7944e-04 - val_loss: 0.0082
# Epoch 99/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.4842e-04 - val_loss: 0.0076
# Epoch 100/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2
300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.9222e-04 - val_loss: 0.0105
# Epoch 140/300
# 47/47 [==============================] - 1s 19ms/step - loss: 1.9575e-04 - val_loss: 0.0086
# Epoch 141/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.1478e-04 - val_loss: 0.0093
# Epoch 142/300
# 47/47 [==============================] - 1s 24ms/step - loss: 2.2019e-04 - val_loss: 0.0092
# Epoch 143/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.1746e-04 - val_loss: 0.0081
# Epoch 144/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.3666e-04 - val_loss: 0.0108
# Epoch 145/300
# 47/47 [==============================] - 1s 16ms/step - loss: 3.0784e-04 - val_loss: 0.0127
# Epoch 146/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.3470e-04 - val_loss: 0.0101
# Epoch 147/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1482e-04 - val_loss: 0.0115
# Epoch 148/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.7581e-04 - val_loss: 0.0092
# Epoch 149/300
# 47/47 [==============================] - 1s 17ms/step - loss: 2.0168e-04 - val_loss: 0.0151
# Epoch 150/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.0992e-04 - val_loss: 0.0145
# Epoch 151/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.4244e-04 - val_loss: 0.0099
# Epoch 152/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.2360e-04 - val_loss: 0.0100
# Epoch 153/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1530e-04 - val_loss: 0.0082
# Epoch 154/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1767e-04 - val_loss: 0.0067
# Epoch 155/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1441e-04 - val_loss: 0.0129
# Epoch 156/300
# 47/47 [==============================] - 1s 18ms/step - loss: 2.0907e-04 - val_loss: 0.0075
# Epoch 157/300
# 47/47 [==============================] - 1s 28ms/step - loss: 1.8854e-04 - val_loss: 0.0069
# Epoch 158/300
# 47/47 [==============================] - 1s 25ms/step - loss: 1.8919e-04 - val_loss: 0.0089
# Epoch 159/300
# 47/47 [==============================] - 1s 25ms/step - loss: 2.0191e-04 - val_loss: 0.0078
# Epoch 160/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.0866e-04 - val_loss: 0.0072
# Epoch 161/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.8645e-04 - val_loss: 0.0085
# Epoch 162/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.9905e-04 - val_loss: 0.0122
# Epoch 163/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.0139e-04 - val_loss: 0.0064
# Epoch 164/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.0246e-04 - val_loss: 0.0096
# Epoch 165/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.9044e-04 - val_loss: 0.0134
# Epoch 166/300
# 47/47 [==============================] - 1s 17ms/step - loss: 2.0379e-04 - val_loss: 0.0085
# Epoch 167/300
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1551e-04 - val_loss: 0.0091
# Epoch 168/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.7175e-04 - val_loss: 0.0113
# Epoch 169/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.8215e-04 - val_loss: 0.0110
# Epoch 170/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.8470e-04 - val_loss: 0.0073
# Epoch 171/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.7407e-04 - val_loss: 0.0082
# Epoch 172/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.9431e-04 - val_loss: 0.0092
# Epoch 173/300
# 47/47 [==============================] - 1s 27ms/step - loss: 1.8740e-04 - val_loss: 0.0067
# Epoch 174/300
# 47/47 [==============================] - 1s 25ms/step - loss: 1.8190e-04 - val_loss: 0.0094
# Epoch 175/300
# 47/47 [==============================] - 1s 25ms/step - loss: 1.7778e-04 - val_loss: 0.0082
# Epoch 176/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.8283e-04 - val_loss: 0.0083
# Epoch 177/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.7657e-04 - val_loss: 0.0076
# Epoch 178/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.7463e-04 - val_loss: 0.0107
# Epoch 179/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.8288e-04 - val_loss: 0.0085
# Epoch 180/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.6790e-04 - val_loss: 0.0096
# Epoch 181/300
# 47/47 [==============================] - 1s 15ms/step - loss: 1.5807e-04 - val_loss: 0.0102
# Epoch 182/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.
300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.6101e-04 - val_loss: 0.0071
# Epoch 275/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4738e-04 - val_loss: 0.0097
# Epoch 276/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4271e-04 - val_loss: 0.0084
# Epoch 277/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4620e-04 - val_loss: 0.0082
# Epoch 278/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4694e-04 - val_loss: 0.0088
# Epoch 279/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.4760e-04 - val_loss: 0.0122
# Epoch 280/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3446e-04 - val_loss: 0.0095
# Epoch 281/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4514e-04 - val_loss: 0.0099
# Epoch 282/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3710e-04 - val_loss: 0.0093
# Epoch 283/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4569e-04 - val_loss: 0.0069
# Epoch 284/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4719e-04 - val_loss: 0.0067
# Epoch 285/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.6733e-04 - val_loss: 0.0079
# Epoch 286/300
# 47/47 [==============================] - 1s 18ms/step - loss: 1.5316e-04 - val_loss: 0.0117
# Epoch 287/300
# 47/47 [==============================] - 1s 26ms/step - loss: 1.3828e-04 - val_loss: 0.0093
# Epoch 288/300
# 47/47 [==============================] - 1s 25ms/step - loss: 1.5732e-04 - val_loss: 0.0068
# Epoch 289/300
# 47/47 [==============================] - 1s 25ms/step - loss: 1.4791e-04 - val_loss: 0.0109
# Epoch 290/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3882e-04 - val_loss: 0.0087
# Epoch 291/300
# 47/47 [==============================] - 1s 17ms/step - loss: 1.5690e-04 - val_loss: 0.0090
# Epoch 292/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.5223e-04 - val_loss: 0.0083
# Epoch 293/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3021e-04 - val_loss: 0.0106
# Epoch 294/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.6283e-04 - val_loss: 0.0118
# Epoch 295/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4429e-04 - val_loss: 0.0097
# Epoch 296/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3006e-04 - val_loss: 0.0068
# Epoch 297/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.4620e-04 - val_loss: 0.0080
# Epoch 298/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.5069e-04 - val_loss: 0.0096
# Epoch 299/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.6549e-04 - val_loss: 0.0096
# Epoch 300/300
# 47/47 [==============================] - 1s 16ms/step - loss: 1.2778e-04 - val_loss: 0.0103

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

# RMSE 계산 함수
def calculate_rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# 모델 평가
predictions = model.predict(X_test)

# 평가 지표 계산
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = calculate_rmse(y_test, predictions)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
# Out:
# 15/15 [==============================] - 1s 8ms/step
# MSE: 0.010272179974127976
# MAE: 0.0983017812110191
# RMSE: 0.10135176354720216

# %%
import matplotlib.pyplot as plt

# 전체 데이터에 대한 스케일을 원래대로 되돌림
predictions_rescaled = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], scaled_data.shape[1] - 1))), axis=1))[:, 3]  # 'Close' 컬럼의 인덱스가 3이라고 가정

# 실제 'Close' 값이 스케일링된 상태라면, 이를 원래의 스케일로 되돌려야 합니다.
y_test_rescaled = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], scaled_data.shape[1] - 1))), axis=1))[:, 3]  # 'Close' 컬럼의 인덱스가 3이라고 가정

# 실제 값과 예측 값을 플로팅
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', color='blue', marker='o')
plt.plot(predictions, label='Predicted', color='red', linestyle='--')
plt.title('LSTM Model Predictions vs Actual (AAPL - VADER)')
plt.xlabel('Time Point')
plt.ylabel('Value')
plt.legend()
plt.show()
